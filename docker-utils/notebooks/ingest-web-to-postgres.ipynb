# %%
import pandas as pd
from sqlalchemy import create_engine

# %%
# Download data from DE-zoomcamp github - https://github.com/DataTalksClub/nyc-tlc-data/releases/tag/yellow

# %%
df = pd.read_csv("../data/yellow_tripdata_2021-01.csv")
# Out:
# /var/folders/nx/wmysyswj23sfwkb68fjfms0w0000gn/T/ipykernel_43446/201002070.py:1: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv("data/yellow_tripdata_2021-01.csv")

# %%
df
# Out:
#          VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1.0  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1             1.0  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2             1.0  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3             1.0  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4             2.0  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ...           ...                  ...                   ...              ...
# 1369760       NaN  2021-01-25 08:32:04   2021-01-25 08:49:32              NaN
# 1369761       NaN  2021-01-25 08:34:00   2021-01-25 09:04:00              NaN
# 1369762       NaN  2021-01-25 08:37:00   2021-01-25 08:53:00              NaN
# 1369763       NaN  2021-01-25 08:28:00   2021-01-25 08:50:00              NaN
# 1369764       NaN  2021-01-25 08:38:00   2021-01-25 08:50:00              NaN
#
# ...

# %%
df.describe()
# Out:
#            VendorID  passenger_count  trip_distance    RatecodeID  \
# count  1.271413e+06     1.271413e+06   1.369765e+06  1.271413e+06
# mean   1.676925e+00     1.411508e+00   4.631982e+00  1.035081e+00
# std    4.676513e-01     1.059833e+00   3.939042e+02  5.994840e-01
# min    1.000000e+00     0.000000e+00   0.000000e+00  1.000000e+00
# 25%    1.000000e+00     1.000000e+00   1.000000e+00  1.000000e+00
# 50%    2.000000e+00     1.000000e+00   1.700000e+00  1.000000e+00
# 75%    2.000000e+00     1.000000e+00   3.020000e+00  1.000000e+00
# max    2.000000e+00     8.000000e+00   2.631633e+05  9.900000e+01
#
#        PULocationID  DOLocationID  payment_type   fare_amount         extra  \
# count  1.369765e+06  1.369765e+06  1.271413e+06  1.369765e+06  1.369765e+06
# mean   1.652472e+02  1.614956e+02  1.280521e+00  1.209662e+01  9.705085e-01
# std    6.783849e+01  7.210800e+01  4.916921e-01  1.291338e+01  1.231256e+00
# ...

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data' ))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" REAL,
#   "tpep_pickup_datetime" TEXT,
#   "tpep_dropoff_datetime" TEXT,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])

# %%
print(pd.io.sql.get_schema(df, name='yellow_taxi_data' ))
# Out:
# CREATE TABLE "yellow_taxi_data" (
# "VendorID" REAL,
#   "tpep_pickup_datetime" TIMESTAMP,
#   "tpep_dropoff_datetime" TIMESTAMP,
#   "passenger_count" REAL,
#   "trip_distance" REAL,
#   "RatecodeID" REAL,
#   "store_and_fwd_flag" TEXT,
#   "PULocationID" INTEGER,
#   "DOLocationID" INTEGER,
#   "payment_type" REAL,
#   "fare_amount" REAL,
#   "extra" REAL,
#   "mta_tax" REAL,
#   "tip_amount" REAL,
#   "tolls_amount" REAL,
#   "improvement_surcharge" REAL,
#   "total_amount" REAL,
#   "congestion_surcharge" REAL
# )

# %%
engine = create_engine('postgresql://root:root@localhost:5432/ny_taxi')

# %%
engine.connect()

# %%
# If we pass the engine, then pd.io returns the schema for postgres.

print(pd.io.sql.get_schema(df, name='yellow_taxi_data', con=engine ))
# Out:
# CREATE TABLE yellow_taxi_data (
# 	"VendorID" FLOAT(53),
# 	tpep_pickup_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	tpep_dropoff_datetime TIMESTAMP WITHOUT TIME ZONE,
# 	passenger_count FLOAT(53),
# 	trip_distance FLOAT(53),
# 	"RatecodeID" FLOAT(53),
# 	store_and_fwd_flag TEXT,
# 	"PULocationID" BIGINT,
# 	"DOLocationID" BIGINT,
# 	payment_type FLOAT(53),
# 	fare_amount FLOAT(53),
# 	extra FLOAT(53),
# 	mta_tax FLOAT(53),
# 	tip_amount FLOAT(53),
# 	tolls_amount FLOAT(53),
# 	improvement_surcharge FLOAT(53),
# 	total_amount FLOAT(53),
# 	congestion_surcharge FLOAT(53)
# )

# %%
# To ingest the data in postgres, we use iterators to chunk the data and load in small chunks to avoid loading all data in memory

df_iter = pd.read_csv('../data/yellow_tripdata_2021-01.csv', iterator=True, chunksize=100000)

# %%
df_iter

# %%
df = next(df_iter)

# %%
df
# Out:
#        VendorID tpep_pickup_datetime tpep_dropoff_datetime  passenger_count  \
# 0             1  2021-01-01 00:30:10   2021-01-01 00:36:12              1.0
# 1             1  2021-01-01 00:51:20   2021-01-01 00:52:19              1.0
# 2             1  2021-01-01 00:43:30   2021-01-01 01:11:06              1.0
# 3             1  2021-01-01 00:15:48   2021-01-01 00:31:01              0.0
# 4             2  2021-01-01 00:31:49   2021-01-01 00:48:21              1.0
# ...         ...                  ...                   ...              ...
# 99995         1  2021-01-04 14:04:31   2021-01-04 14:08:52              3.0
# 99996         1  2021-01-04 14:18:46   2021-01-04 14:35:45              2.0
# 99997         1  2021-01-04 14:42:41   2021-01-04 14:59:22              2.0
# 99998         2  2021-01-04 14:39:02   2021-01-04 15:09:37              2.0
# 99999         2  2021-01-04 14:49:36   2021-01-04 14:54:44              5.0
#
# ...

# %%
# To ingest
# 1. Create a table in postgres with the required schema - use df.head(0) for create table statement.
# 2. Ingest data in chunks - use df.to_sql()
# 3. Ingest all chunks

# %%
df.head(0)
# Out:
# Empty DataFrame
# Columns: [VendorID, tpep_pickup_datetime, tpep_dropoff_datetime, passenger_count, trip_distance, RatecodeID, store_and_fwd_flag, PULocationID, DOLocationID, payment_type, fare_amount, extra, mta_tax, tip_amount, tolls_amount, improvement_surcharge, total_amount, congestion_surcharge, airport_fee]
# Index: []

# %%
# Create a new table and replace if exists
df.head(0).to_sql(name='yellow_taxi_data', con=engine, if_exists='replace')
# Out:
# 0

# %%
# write data using append
# %time df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
# Out:
# CPU times: user 2.92 s, sys: 365 ms, total: 3.29 s
# Wall time: 5.82 s
# 1000

# %%
from time import time

# %%
while True:
    t_start = time()
    df = next(df_iter)
    df['tpep_pickup_datetime'] = pd.to_datetime(df['tpep_pickup_datetime'])
    df['tpep_dropoff_datetime'] = pd.to_datetime(df['tpep_dropoff_datetime'])
    df.to_sql(name='yellow_taxi_data', con=engine, if_exists='append')
    t_end = time()
    print(f"Inserted another chunk, took {t_end-t_start} seconds.")
# Out:
# Inserted another chunk, took 6.668690919876099 seconds.
# Inserted another chunk, took 6.385930061340332 seconds.
# Inserted another chunk, took 6.395248174667358 seconds.
# Inserted another chunk, took 6.294620990753174 seconds.
# Inserted another chunk, took 6.506405830383301 seconds.
# Inserted another chunk, took 6.135457992553711 seconds.
# Inserted another chunk, took 6.7499871253967285 seconds.
# Inserted another chunk, took 7.104039907455444 seconds.
# Inserted another chunk, took 7.579696893692017 seconds.
# Inserted another chunk, took 7.064464330673218 seconds.
# Inserted another chunk, took 6.668454170227051 seconds.
# /var/folders/nx/wmysyswj23sfwkb68fjfms0w0000gn/T/ipykernel_43446/3049434981.py:3: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = next(df_iter)
# Inserted another chunk, took 6.439601898193359 seconds.
# Inserted another chunk, took 3.8881449699401855 seconds.
# ...
